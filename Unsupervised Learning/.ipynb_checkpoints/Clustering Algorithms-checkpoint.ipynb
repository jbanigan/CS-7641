# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, adjusted_mutual_info_score, silhouette_score, homogeneity_score
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.mixture import GaussianMixture
import warnings
warnings.filterwarnings("ignore")

# %%
data_selection =    1    # 0 for wine, 1 for cancer

# %%
wine = pd.read_csv('data/wine.csv',sep=';')
bins = (2, 6.5, 8)
group_names = ['bad','good']
wine['quality'] = pd.cut(wine['quality'], bins=bins,labels=group_names)
wine = wine.dropna()
wine_label_quality = LabelEncoder()
wine['quality'] = wine_label_quality.fit_transform(wine['quality'])

cancer = pd.read_csv('data/cancer.csv')
cancer = cancer.dropna()
cancer['class']=cancer['class'].map({4:1, 2:0})

if data_selection == 0:
    X = wine.drop('quality',axis=1)
    y = wine['quality']
    y_save = y
    dataset = 'Wine Dataset'
elif data_selection == 1:
    X = cancer.drop(['id','class'],axis=1)
    y = cancer['class'] 
    y_save = y
    dataset = 'Cancer Dataset'
else:
    print("0 for wine, 1 for cancer")

# %%
min_max_scaler = MinMaxScaler()
X = min_max_scaler.fit_transform(X)

# %% [markdown]
# # K-Means

# %%
clusters = np.arange(3, 41, 1)

# %%
inertia =[]
for cluster in clusters:
    kmeans = KMeans(n_clusters=cluster,
                    max_iter=1000,
                    random_state=44).fit(X)
    
    inertia.append(kmeans.inertia_)
    
plt.figure()
plt.plot(clusters, inertia,'b')
plt.xlabel('No. of clusters')
plt.ylabel('Inertia')
plt.title('SSE/Inertia vs No. of Clusters')
plt.savefig('img/SSE vs clusters - '+dataset+'.png')
plt.show()

# %%
S = []
H = []
for cluster in clusters:
    kmeans = KMeans(n_clusters=cluster, n_init=50, max_iter=1000, random_state=44, 
                    n_jobs=-2).fit(X)
    label = kmeans.labels_
    ss = silhouette_score(X, label, metric='euclidean')
    hs = homogeneity_score(y, label)
    S.append(ss)
    H.append(hs)
    
plt.figure()
plt.plot(clusters, S, 'r', label="Silhouette")
plt.plot(clusters, H, 'b', label="Homogeneity")
plt.legend()
plt.ylabel("Scores")
plt.xlabel('No. of clusters')
plt.title('SS & HS vs No. of clusters')
plt.savefig('img/SS&HS vs clusters - '+dataset+'.png')
plt.show()

# %% [markdown]
# # Expectation Maximization

# %%
silh_EM = {}
homog_EM = {}
log_likelihood_EM = {}
for cluster in clusters:
    gmm = GaussianMixture(n_components=cluster, max_iter=100, random_state=44, 
                          n_init=5).fit(X)
    label = gmm.predict(X)
    sil_coeff = silhouette_score(X, label, metric='euclidean')
    homog_score = homogeneity_score(y, label)
    silh_EM[cluster] = sil_coeff
    homog_EM[cluster] = homog_score
    log_likelihood_EM[cluster] = gmm.score(X)
   
plt.figure()
plt.plot(list(silh_EM.keys()), list(silh_EM.values()), 'r', label="Silhouette")
plt.plot(list(homog_EM.keys()), list(homog_EM.values()), 'g', label="Homogeneity")
plt.legend()
plt.xlabel("Number of cluster")
plt.ylabel("Silhouette Coefficient")
# Out:
# For n_clusters=2, The Silhouette Coefficient is 0.4155386646984106
# For n_clusters=2, The homogeneity_score is 0.5722966909207493
# For n_clusters=2, The log_likelihood score is 10.199173974247707
# For n_clusters=3, The Silhouette Coefficient is 0.31824321949291046
# For n_clusters=3, The homogeneity_score is 0.5818789362552834
# For n_clusters=3, The log_likelihood score is 11.775515319300704
# For n_clusters=4, The Silhouette Coefficient is 0.2696233418006718
# For n_clusters=4, The homogeneity_score is 0.6300877552370918
# For n_clusters=4, The log_likelihood score is 13.905524779644363
# For n_clusters=5, The Silhouette Coefficient is 0.08393999015844637
# For n_clusters=5, The homogeneity_score is 0.7418487661007386
# For n_clusters=5, The log_likelihood score is 14.218895829677827
# For n_clusters=6, The Silhouette Coefficient is 0.10500892009042903
# For n_clusters=6, The homogeneity_score is 0.8021997330970975
# For n_clusters=6, The log_likelihood score is 15.289105063496772
# For n_clusters=7, The Silhouette Coefficient is 0.09392759576197594
# For n_clusters=7, The homogeneity_score is 0.8232140846390198
# For n_clusters=7, The log_likelihood score is 14.971481383868417
# For n_clusters=8, The Silhouette Coefficient is 0.05406152029099663
# For n_clusters=8, The homogeneity_score is 0.7361239449509617
# For n_clusters=8, The log_likelihood score is 15.794246661859617
# For n_clusters=9, The Silhouette Coefficient is 0.08777034801910233
# For n_clusters=9, The homogeneity_score is 0.8143465760199078
# For n_clusters=9, The log_likelihood score is 15.535717261965097
# For n_clusters=10, The Silhouette Coefficient is 0.07727468877552042
# For n_clusters=10, The homogeneity_score is 0.8324194276538879
# For n_clusters=10, The log_likelihood score is 15.526097211099637
# For n_clusters=11, The Silhouette Coefficient is 0.05003015079962278
# For n_clusters=11, The homogeneity_score is 0.7814365657524146
# For n_clusters=11, The log_likelihood score is 17.857189626367
# For n_clusters=12, The Silhouette Coefficient is 0.05016611422895108
# For n_clusters=12, The homogeneity_score is 0.7715185175094136
# For n_clusters=12, The log_likelihood score is 17.87783388583433
# For n_clusters=13, The Silhouette Coefficient is 0.054775590838397045
# For n_clusters=13, The homogeneity_score is 0.7897976950926142
# For n_clusters=13, The log_likelihood score is 18.091905793963313
# For n_clusters=14, The Silhouette Coefficient is 0.04630775219468114
# For n_clusters=14, The homogeneity_score is 0.7775660867227636
# For n_clusters=14, The log_likelihood score is 18.441018494072843
# For n_clusters=15, The Silhouette Coefficient is 0.05924412135908319
# For n_clusters=15, The homogeneity_score is 0.7962373153949558
# For n_clusters=15, The log_likelihood score is 19.75604098821193
# For n_clusters=16, The Silhouette Coefficient is 0.05340636375132915
# For n_clusters=16, The homogeneity_score is 0.7932453427687226
# For n_clusters=16, The log_likelihood score is 20.116754250499046
# For n_clusters=17, The Silhouette Coefficient is 0.0668320849100266
# For n_clusters=17, The homogeneity_score is 0.7840290743380446
# For n_clusters=17, The log_likelihood score is 19.32118726057626
# For n_clusters=18, The Silhouette Coefficient is 0.02100551584804812
# For n_clusters=18, The homogeneity_score is 0.7300296682603734
# For n_clusters=18, The log_likelihood score is 19.69321876795769
# For n_clusters=19, The Silhouette Coefficient is 0.01865498228191802
# For n_clusters=19, The homogeneity_score is 0.7342300396396783
# For n_clusters=19, The log_likelihood score is 19.726754585784416
# For n_clusters=20, The Silhouette Coefficient is 0.020199496830507795
# For n_clusters=20, The homogeneity_score is 0.7306641955969959
# For n_clusters=20, The log_likelihood score is 19.663346716623
# For n_clusters=21, The Silhouette Coefficient is 0.008396091279675983
# For n_clusters=21, The homogeneity_score is 0.7960869265753221
# For n_clusters=21, The log_likelihood score is 19.007605441015695
# For n_clusters=22, The Silhouette Coefficient is 0.06746073843977657
# For n_clusters=22, The homogeneity_score is 0.8525660269506584
# For n_clusters=22, The log_likelihood score is 19.33826481725495
# For n_clusters=23, The Silhouette Coefficient is 0.0553893190194219
# For n_clusters=23, The homogeneity_score is 0.8654105646344495
# For n_clusters=23, The log_likelihood score is 21.340500815263976
# For n_clusters=24, The Silhouette Coefficient is 0.07143843514212286
# For n_clusters=24, The homogeneity_score is 0.8525868857792805
# For n_clusters=24, The log_likelihood score is 20.808190630433973
# For n_clusters=25, The Silhouette Coefficient is 0.1246027388465034
# For n_clusters=25, The homogeneity_score is 0.8622634122880493
# For n_clusters=25, The log_likelihood score is 20.787134857811406
# For n_clusters=26, The Silhouette Coefficient is 0.12514975642508938
# For n_clusters=26, The homogeneity_score is 0.8605741207040092
# For n_clusters=26, The log_likelihood score is 20.611150770505308
# For n_clusters=27, The Silhouette Coefficient is 0.12354924955732598
# For n_clusters=27, The homogeneity_score is 0.8611244911719078
# For n_clusters=27, The log_likelihood score is 20.892388762473317
# For n_clusters=28, The Silhouette Coefficient is 0.06627721639301094
# For n_clusters=28, The homogeneity_score is 0.8680261188385243
# For n_clusters=28, The log_likelihood score is 19.423772824257274
# For n_clusters=29, The Silhouette Coefficient is 0.06492446231921271
# For n_clusters=29, The homogeneity_score is 0.8680261188385245
# For n_clusters=29, The log_likelihood score is 19.770236527304714
# For n_clusters=30, The Silhouette Coefficient is 0.088575909540959
# For n_clusters=30, The homogeneity_score is 0.8660258436617677
# For n_clusters=30, The log_likelihood score is 22.161385961377757

# %%
# Out:
# Text(0, 0.5, 'Silhouette Coefficient')

# %%
gmm = GaussianMixture(n_components=2, max_iter=100, random_state=44, 
                      n_init=5).fit(X)
label = gmm.predict(X)
accuracy_score((1-label), y)
# Out:
# 0.8726207906295754
